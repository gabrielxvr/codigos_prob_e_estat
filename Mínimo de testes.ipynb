# %%
import numpy as np

# %%
import random

# %%
def p_ou_n(x):
    if x > 1:
        y = True
    else:
        y = False
    
    return y

# %%
t = 0
lista_de_casos = []
lista_1 = [2, 2, 2, 2, 2, 2, 2, 2, 2, 0]
while t < 1000:
    i = p_ou_n(random.choice(lista_1))
    lista_de_casos.append(i)
    t = t + 1
    
lista_de_casos
# Out:
# [True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
p = 0
n = 0
for a in lista_de_casos:
    if a == True:
        n = n + 1
    if a == False:
        p = p + 1

# %%
print(n, p)
# Out:
# 890 110

# %%
split = np.array_split(lista_de_casos, 625)

split_items = []

for i in split:
   split_items.append(list(i))

split_items
# Out:
# [[True, True],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, False],
#  [True, True],
#  [True, True],
#  [True, True],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [False, True],
#  [True, True],
#  [False, True],
#  [True, True],
#  [True, True],
#  [False, False],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, False],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, False],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, False],
#  [True, True],
#  [False, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
#  [True, True],
# ...

# %%
#chunked_list = list()
#chunk_size = 3

#for i in range(0, len(lista_de_casos), chunk_size):
#    chunked_list.append(lista_de_casos[i:i+chunk_size])

#print(chunked_list)

# %%
split_items_2 = []
for i in split_items:
    m = True
    for j in i:
        m = m*j
    
    if m == False:
        split_items_2.append(i)

# %%
print(len(split_items_2))
# Out:
# 101

# %%
# s é o número seções por vez
# n é o tamanho da lista, ou quantidade de indivíduos
# p é a probabilidade em porcentagem de o resultado dar positivo

def numero_de_testes(s, n, p):
    
    lista_prob = []
    for i in range(1, 101):
        lista_prob.append(i)
        
    
    
    
    t = 0
    lista_de_casos = []
    while t < n:
        i = p_ou_n(random.choice(lista_1))
        lista_de_casos.append(i)
        t = t + 1
        
    lista_de_casos
